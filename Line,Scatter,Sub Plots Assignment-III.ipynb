# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_mfbn=pd.read_csv('most_frequent_baby_names.csv')
df_mfbn.head()
# Out:
#    Order    Name  Gender  Year  Frequency
# 0      1   LAURA  Female  1996        237
# 1      2   MARIA  Female  1996        219
# 2      3   MARTA  Female  1996        206
# 3      4  ANDREA  Female  1996        199
# 4      5    ANNA  Female  1996        195

# %%
table=pd.pivot_table(data=df_mfbn,index="Name",values="Frequency",aggfunc=np.sum)
table
# Out:
#            Frequency
# Name
# ABRIL            400
# ADRIA           1532
# ADRIAN           140
# AINA            1368
# AINHOA           113
# ...              ...
# SOFIA           1141
# VALENTINA        412
# VALERIA           55
# VICTOR          2010
# XAVIER           565
#
# [97 rows x 1 columns]

# %%
plt.figure(figsize=(15,10))
plt.plot(table.index,table["Frequency"])
plt.xticks(rotation=90)
plt.xlabel('Name')
plt.ylabel('NUMBER OF PEOPLE WITH THAT NAME')
plt.title('Name vs NUMBER OF PEOPLE WITH THAT NAME')
plt.savefig('hwlp1.png',dpi=300)
plt.show()

# %%
df_bs=pd.read_csv('births.csv')
df_bs.head()
# Out:
#    Year  District Code District Name  Neighborhood Code  \
# 0  2017              1  Ciutat Vella                  1
# 1  2017              1  Ciutat Vella                  2
# 2  2017              1  Ciutat Vella                  3
# 3  2017              1  Ciutat Vella                  4
# 4  2017              2      Eixample                  5
#
#                             Neighborhood Gender  Number
# 0                               el Raval   Boys     283
# 1                         el Barri Gòtic   Boys      56
# 2                         la Barceloneta   Boys      51
# 3  Sant Pere, Santa Caterina i la Ribera   Boys      90
# 4                          el Fort Pienc   Boys     117

# %%
table2=pd.pivot_table(data=df_bs,index="District Name",values="Number",aggfunc=np.sum)
table2
# Out:
#                      Number
# District Name
# Ciutat Vella           4073
# Eixample              10357
# Gràcia                 5263
# Horta-Guinardó         6675
# Les Corts              3127
# No consta                11
# Nou Barris             7062
# Sant Andreu            6423
# Sant Martí            10368
# Sants-Montjuïc         7499
# Sarrià-Sant Gervasi    6490

# %%
plt.figure(figsize=(15,10))
plt.plot(table2.index,table2["Number"])
#plt.scatter(table2.index,table2["Number"])
#plt.xticks(rotation=0)
plt.xlabel('DISTRICT NAME')
plt.ylabel('NUMBER OF BIRTHS IN THAT YEAR')
plt.title('DISTRICT NAME vs NUMBER OF BIRTHS IN THAT YEAR')
plt.savefig('hwlp2.png',dpi=300)
plt.show()

# %%
table3=pd.pivot_table(data=df_bs,index="Neighborhood",values="Number",aggfunc=np.sum)
table3
# Out:
#                                Number
# Neighborhood
# Baró de Viver                     119
# Can Baró                          344
# Can Peguera                        78
# Canyelles                         235
# Ciutat Meridiana                  533
# ...                               ...
# la Vila Olímpica del Poblenou     432
# la Vila de Gràcia                2366
# les Corts                        1813
# les Roquetes                      775
# les Tres Torres                   710
#
# [75 rows x 1 columns]

# %%
plt.figure(figsize=(15,10))
plt.scatter(table3.index,table3["Number"])
plt.xticks(rotation=90)
plt.xlabel('YEAR')
plt.ylabel('NUMBER OF BIRTHS IN THAT YEAR')
plt.title('YEAR vs NUMBER OF BIRTHS IN THAT YEAR')
plt.savefig('hwsp1.png',dpi=300)
plt.show()

# %%
df_ieba=pd.read_csv('immigrants_emigrants_by_agen.csv')
df_ieba.head()
# Out:
#      Year  District Code District Name  Neighborhood Code  \
# 0  2017.0            1.0  Ciutat Vella                1.0
# 1  2017.0            1.0  Ciutat Vella                2.0
# 2  2017.0            1.0  Ciutat Vella                3.0
# 3  2017.0            1.0  Ciutat Vella                4.0
# 4  2017.0            2.0      Eixample                5.0
#
#                        Neighborhood Name  Age  Immigrants  Emigrants
# 0                               el Raval  0-4       154.0      108.0
# 1                         el Barri Gòtic  0-4        58.0       33.0
# 2                         la Barceloneta  0-4        38.0       37.0
# 3  Sant Pere, Santa Caterina i la Ribera  0-4        56.0       55.0
# 4                          el Fort Pienc  0-4        79.0       60.0

# %%
table4=pd.pivot_table(data=df_ieba,index="District Name",values="Immigrants",aggfunc=np.sum)
table4
# Out:
#                      Immigrants
# District Name
# Ciutat Vella            12611.0
# Eixample                19047.0
# Gràcia                   7254.0
# Horta-Guinardó           7799.0
# Les Corts                4375.0
# No consta                   2.0
# Nou Barris               8274.0
# Sant Andreu              6335.0
# Sant Martí              12720.0
# Sants-Montjuïc          11683.0
# Sarrià-Sant Gervasi      7227.0

# %%
table5=pd.pivot_table(data=df_ieba,index="District Name",values="Emigrants",aggfunc=np.sum)
table5
# Out:
#                      Emigrants
# District Name
# Ciutat Vella            4629.0
# Eixample                8883.0
# Gràcia                  3807.0
# Horta-Guinardó          4860.0
# Les Corts               2659.0
# No consta                  4.0
# Nou Barris              5061.0
# Sant Andreu             4214.0
# Sant Martí              7362.0
# Sants-Montjuïc          7136.0
# Sarrià-Sant Gervasi     4037.0

# %%
plt.figure(figsize=(15,10))
plt.scatter(table4.index,table4["Immigrants"],color='red')
plt.scatter(table5.index,table5["Emigrants"])
#plt.xticks(rotation=90)
plt.xlabel('District Name')
plt.ylabel('Immigrants and Emmigrants')
plt.title('District Name vs Immigrants-red and Emmigrants-blue')
plt.savefig('hwsp2.png',dpi=300)
plt.show()

# %%
fig,ax=plt.subplots(nrows=1,ncols=2,figsize=(30,20))

ax[0].scatter(table4.index,table4["Immigrants"],color='red')
ax[0].set_xlabel('District Name')
ax[0].set_ylabel('Immigrants and Emmigrants')
ax[0].set_title('District Name vs Immigrants-red and Emmigrants-blue')

ax[1].scatter(table5.index,table5["Emigrants"])
ax[1].set_xlabel('District Name')
ax[1].set_ylabel('Immigrants and Emmigrants')
ax[1].set_title('District Name vs Immigrants-red and Emmigrants-blue')

plt.show()
plt.savefig('subplotshw1.png')

# %%
fig,ax=plt.subplots(nrows=1,ncols=2,figsize=(30,20))

ax[0].plot(table2.index,table2["Number"])
ax[0].set_xlabel('DISTRICT NAME')
ax[0].set_ylabel('NUMBER OF BIRTHS IN THAT YEAR')
ax[0].set_title('DISTRICT NAME vs NUMBER OF BIRTHS IN THAT YEAR')

ax[1].plot(table.index,table["Frequency"])
ax[1].set_xlabel('Name')
ax[1].set_ylabel('NUMBER OF PEOPLE WITH THAT NAME')
ax[1].set_title('Name vs NUMBER OF PEOPLE WITH THAT NAME')

plt.show()
plt.savefig('subplotshw2.png')
